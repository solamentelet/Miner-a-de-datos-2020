# %% [markdown]
# # Práctica 1: Primera exploración a los datos

# %% [markdown]
# # Top 50 songs listened in 2019 on spotify

# %%
conda install -c conda-forge/label/gcc7 missingno
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'top50.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
# Unnamed: 0          50 non-null int64
# Track.Name          50 non-null object
# Artist.Name         50 non-null object
# Genre               50 non-null object
# Beats.Per.Minute    50 non-null int64
# Energy              50 non-null int64
# Danceability        50 non-null int64
# Loudness..dB..      50 non-null int64
# Liveness            50 non-null int64
# Valence.            50 non-null int64
# Length.             50 non-null int64
# Acousticness..      50 non-null int64
# Speechiness.        50 non-null int64
# Popularity          50 non-null int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
df.shape#para ver las dimensiones del conjunto de datos
# Out:
# (50, 14)

# %%
df.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'Track.Name',
#  'Artist.Name',
#  'Genre',
#  'Beats.Per.Minute',
#  'Energy',
#  'Danceability',
#  'Loudness..dB..',
#  'Liveness',
#  'Valence.',
#  'Length.',
#  'Acousticness..',
#  'Speechiness.',
#  'Popularity']

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# Track.Name          object
# Artist.Name         object
# Genre               object
# Beats.Per.Minute     int64
# Energy               int64
# Danceability         int64
# Loudness..dB..       int64
# Liveness             int64
# Valence.             int64
# Length.              int64
# Acousticness..       int64
# Speechiness.         int64
# Popularity           int64
# dtype: object

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True) #espacios reemplazados con nan

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
msno.bar(df) #todo lo que este debajo del 80

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# []

# %%
df.describe()
# Out:
#        Unnamed: 0  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count    50.00000         50.000000  50.000000      50.00000       50.000000
# mean     25.50000        120.060000  64.060000      71.38000       -5.660000
# std      14.57738         30.898392  14.231913      11.92988        2.056448
# min       1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%      13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%      25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%      37.75000        137.500000  74.750000      79.75000       -4.000000
# max      50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# ...

# %%
df.loc[[0]]
# Out:
#    Unnamed: 0 Track.Name   Artist.Name         Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes  canadian pop               117
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
#
#    Acousticness..  Speechiness.  Popularity
# 0               4             3          79

# %%
df.loc[:2400]
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
df[1:5].head() #df.tail(-100) )
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 1      302               8             9          92
# 2      186              12            46          85
# ...

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#     Unnamed: 0                             Track.Name    Artist.Name  \
# 0            1                               Señorita   Shawn Mendes
# 5            6      I Don't Care (with Justin Bieber)     Ed Sheeran
# 6            7                                 Ransom      Lil Tecca
# 7            8                      How Do You Sleep?      Sam Smith
# 8            9                  Old Town Road - Remix      Lil Nas X
# 9           10                                bad guy  Billie Eilish
# 10          11                               Callaita      Bad Bunny
# 11          12  Loco Contigo (feat. J. Balvin & Tyga)       DJ Snake
# 12          13                      Someone You Loved  Lewis Capaldi
# 13          14                     Otro Trago - Remix           Sech
#
#              Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# 0     canadian pop               117      55            76              -6
# ...

# %%
df.Popularity.values
# Out:
# array([79, 92, 85, 86, 94, 84, 92, 90, 87, 95, 93, 86, 88, 87, 92, 82, 90,
#        91, 88, 91, 91, 91, 83, 91, 89, 70, 83, 89, 91, 89, 84, 89, 89, 89,
#        89, 89, 91, 87, 80, 78, 88, 90, 87, 84, 88, 88, 88, 88, 88, 82],
#       dtype=int64)

# %%
df['Popularity'].values
# Out:
# array([79, 92, 85, 86, 94, 84, 92, 90, 87, 95, 93, 86, 88, 87, 92, 82, 90,
#        91, 88, 91, 91, 91, 83, 91, 89, 70, 83, 89, 91, 89, 84, 89, 89, 89,
#        89, 89, 91, 87, 80, 78, 88, 90, 87, 84, 88, 88, 88, 88, 88, 82],
#       dtype=int64)

# %%
df.Popularity.unique()
# Out:
# array([79, 92, 85, 86, 94, 84, 90, 87, 95, 93, 88, 82, 91, 83, 89, 70, 80,
#        78], dtype=int64)

# %%
df.Popularity.value_counts()
# Out:
# 89    8
# 88    8
# 91    7
# 87    4
# 92    3
# 90    3
# 84    3
# 86    2
# 82    2
# 83    2
# 78    1
# 79    1
# 80    1
# 95    1
# 85    1
# 94    1
# 93    1
# 70    1
# Name: Popularity, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          Unnamed: 0  Track.Name  Artist.Name  Genre  Beats.Per.Minute  Energy  \
# count            50          50           50     50                50      50
# size             50          50           50     50                50      50
# nunique          50          50           38     21                31      31
#
#          Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# count              50              50        50        50       50
# size               50              50        50        50       50
# nunique            29               9        22        39       44
#
#          Acousticness..  Speechiness.  Popularity
# count                50            50          50
# size                 50            50          50
# nunique              35            24          18

# %%
df.groupby('Popularity').agg(['count', 'size', 'nunique']).stack()
# Out:
#                     Unnamed: 0  Track.Name  Artist.Name  Genre  \
# Popularity
# 70         count             1           1            1      1
#            size              1           1            1      1
#            nunique           1           1            1      1
# 78         count             1           1            1      1
#            size              1           1            1      1
#            nunique           1           1            1      1
# 79         count             1           1            1      1
#            size              1           1            1      1
#            nunique           1           1            1      1
# 80         count             1           1            1      1
#            size              1           1            1      1
#            nunique           1           1            1      1
# 82         count             2           2            2      2
#            size              2           2            2      2
# ...

# %%
df.groupby('Artist.Name').agg(['count', 'size', 'nunique'])
# Out:
#                  Unnamed: 0              Track.Name              Genre       \
#                       count size nunique      count size nunique count size
# Artist.Name
# Ali Gatie                 1    1       1          1    1       1     1    1
# Anuel AA                  1    1       1          1    1       1     1    1
# Ariana Grande             2    2       2          2    2       2     2    2
# Bad Bunny                 1    1       1          1    1       1     1    1
# Billie Eilish             2    2       2          2    2       2     2    2
# Chris Brown               1    1       1          1    1       1     1    1
# DJ Snake                  1    1       1          1    1       1     1    1
# Daddy Yankee              1    1       1          1    1       1     1    1
# Drake                     1    1       1          1    1       1     1    1
# Ed Sheeran                4    4       4          4    4       4     4    4
# ...

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#     Unnamed: 0                                         Track.Name  \
# 27          28                                           It's You
# 35          36  Summer Days (feat. Macklemore & Patrick Stump ...
#
#       Artist.Name             Genre  Beats.Per.Minute  Energy  Danceability  \
# 27      Ali Gatie  canadian hip hop                96      46            73
# 35  Martin Garrix          big room               114      72            66
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 27              -7        19        40      213              37             3
# 35              -7        14        32      164              18             6
#
#     Popularity
# 27          89
# 35          89

# %%
df.shape
# Out:
# (50, 14)

# %%
df_sample.shape
# Out:
# (2, 14)

# %%
df_dropped = df.dropna(subset=['Popularity'])
df_dropped.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df_dropped.shape
# Out:
# (50, 14)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df_copy.shape
# Out:
# (50, 14)

# %%
df_dropped['Energy'].dtype
# Out:
# dtype('int64')

# %%
df_dropped['Energy'].mean()
# Out:
# 64.06

# %%
df_copy['Energy'].fillna(value=np.round(df['Energy'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          Unnamed: 0  Track.Name  Artist.Name  Genre  Beats.Per.Minute  Energy  \
# count            50          50           50     50                50      50
# size             50          50           50     50                50      50
# nunique          50          50           38     21                31      31
#
#          Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# count              50              50        50        50       50
# size               50              50        50        50       50
# nunique            29               9        22        39       44
#
#          Acousticness..  Speechiness.  Popularity
# count                50            50          50
# size                 50            50          50
# nunique              35            24          18

# %% [markdown]
# # Handling Categorical Data

# %%
list(df['Artist.Name'].unique())
# Out:
# ['Shawn Mendes',
#  'Anuel AA',
#  'Ariana Grande',
#  'Ed Sheeran',
#  'Post Malone',
#  'Lil Tecca',
#  'Sam Smith',
#  'Lil Nas X',
#  'Billie Eilish',
#  'Bad Bunny',
#  'DJ Snake',
#  'Lewis Capaldi',
#  'Sech',
#  'Drake',
#  'Chris Brown',
#  'J Balvin',
#  'Y2K',
#  'Lizzo',
#  'MEDUZA',
#  'Jhay Cortez',
#  'Lunay',
#  'Tones and I',
#  'Ali Gatie',
#  'Daddy Yankee',
#  'The Chainsmokers',
#  'Maluma',
#  'Young Thug',
#  'Katy Perry',
#  'Martin Garrix',
#  'Jonas Brothers',
#  'Lauv',
#  'Kygo',
#  'Taylor Swift',
#  'Lady Gaga',
#  'Khalid',
#  'ROSALÍA',
#  'Marshmello',
#  'Nicky Jam']

# %%
df['Artist.Name'].replace({'Nicky Jam':" NJ ", 
                        'Taylor Swift' : "TF"}, 
                          inplace=True)

# %%
list(df['Artist.Name'].unique())
# Out:
# ['Shawn Mendes',
#  'Anuel AA',
#  'Ariana Grande',
#  'Ed Sheeran',
#  'Post Malone',
#  'Lil Tecca',
#  'Sam Smith',
#  'Lil Nas X',
#  'Billie Eilish',
#  'Bad Bunny',
#  'DJ Snake',
#  'Lewis Capaldi',
#  'Sech',
#  'Drake',
#  'Chris Brown',
#  'J Balvin',
#  'Y2K',
#  'Lizzo',
#  'MEDUZA',
#  'Jhay Cortez',
#  'Lunay',
#  'Tones and I',
#  'Ali Gatie',
#  'Daddy Yankee',
#  'The Chainsmokers',
#  'Maluma',
#  'Young Thug',
#  'Katy Perry',
#  'Martin Garrix',
#  'Jonas Brothers',
#  'Lauv',
#  'Kygo',
#  'TF',
#  'Lady Gaga',
#  'Khalid',
#  'ROSALÍA',
#  'Marshmello',
#  ' NJ ']

# %%
keys = list(df['Artist.Name'].unique())
vals = range(1,3)
act = dict(zip(keys, vals))
act
# Out:
# {'Shawn Mendes': 1, 'Anuel AA': 2}

# %%
df_copy['Artist.Name'] = df['Artist.Name'].map(act)
df_copy.head()
# Out:
#    Unnamed: 0                       Track.Name  Artist.Name           Genre  \
# 0           1                         Señorita          1.0    canadian pop
# 1           2                            China          2.0  reggaeton flow
# 2           3    boyfriend (with Social House)          NaN       dance pop
# 3           4  Beautiful People (feat. Khalid)          NaN             pop
# 4           5      Goodbyes (Feat. Young Thug)          NaN         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
list(df_copy['Artist.Name'].unique())
# Out:
# [1.0, 2.0, nan]

# %% [markdown]
# # Data Summarization

# %%
df_copy['Beats.Per.Minute'].mean()
# Out:
# 120.06

# %%
df_copy['Beats.Per.Minute'][df_copy['Beats.Per.Minute'] == 6]
# Out:
# Series([], Name: Beats.Per.Minute, dtype: int64)

# %%
df_copy['Beats.Per.Minute'][df_copy['Beats.Per.Minute'] == 6].mean()
# Out:
# nan

# %%
df_copy.groupby(["Artist.Name", "Beats.Per.Minute", "Popularity"]).count()
# Out:
#                                          Unnamed: 0  Track.Name  Genre  \
# Artist.Name Beats.Per.Minute Popularity
# 1.0         117              79                   1           1      1
#             124              70                   1           1      1
# 2.0         105              92                   1           1      1
#
#                                          Energy  Danceability  Loudness..dB..  \
# Artist.Name Beats.Per.Minute Popularity
# 1.0         117              79               1             1               1
#             124              70               1             1               1
# 2.0         105              92               1             1               1
#
#                                          Liveness  Valence.  Length.  \
# Artist.Name Beats.Per.Minute Popularity
# 1.0         117              79                 1         1        1
#             124              70                 1         1        1
# ...

# %%
df_copy.Popularity
# Out:
# 0     79
# 1     92
# 2     85
# 3     86
# 4     94
# 5     84
# 6     92
# 7     90
# 8     87
# 9     95
# 10    93
# 11    86
# 12    88
# 13    87
# 14    92
# 15    82
# 16    90
# 17    91
# 18    88
# 19    91
# 20    91
# 21    91
# 22    83
# 23    91
# 24    89
# 25    70
# 26    83
# 27    89
# 28    91
# 29    89
# 30    84
# 31    89
# 32    89
# 33    89
# 34    89
# 35    89
# 36    91
# 37    87
# 38    80
# 39    78
# 40    88
# 41    90
# 42    87
# 43    84
# 44    88
# 45    88
# 46    88
# 47    88
# 48    88
# 49    82
# Name: Popularity, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#     Unnamed: 0                                         Track.Name  \
# 27          28                                           It's You
# 35          36  Summer Days (feat. Macklemore & Patrick Stump ...
#
#       Artist.Name             Genre  Beats.Per.Minute  Energy  Danceability  \
# 27      Ali Gatie  canadian hip hop                96      46            73
# 35  Martin Garrix          big room               114      72            66
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 27              -7        19        40      213              37             3
# 35              -7        14        32      164              18             6
#
#     Popularity
# 27          89
# 35          89

# %%
df_sample.groupby(["Artist.Name",  "Popularity"]).agg({'Danceability':np.mean,'Liveness':np.max})
# Out:
#                           Danceability  Liveness
# Artist.Name   Popularity
# Ali Gatie     89                    73        19
# Martin Garrix 89                    66        14
