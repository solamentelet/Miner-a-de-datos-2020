# %% [markdown]
# # Práctica 1: Primera exploración a los datos

# %%
conda install -c conda-forge/label/gcc7 missingno
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'agro.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria prep_deriv  \
# 0  100317506         1       1           1        4          1
# 1  100317506         1       1           1        5          1          2
# 2  100961704         1       1           2        4          1
# 3  100961704         1       1           2        5          1          1
# 4  101917906         1       1           2        7          1
#
#    otro_pago fpago_1 fpago_2  ...   ventas autocons otrosnom  gasneg  \
# 0          2                  ...        0        0        0   80000
# 1          2                  ...   500000        0        0  391000
# 2          1               2  ...        0        0        0   50000
# 3          1               2  ...  2669678        0     1000  336300
# 4          2                  ...       60        0        0     100
#
#   ventas_tri auto_tri otros_tri  gasto_tri    ing_tri   ero_tri
# 0       0.00      0.0       0.0   19565.21       0.00  19563.26
# 1  122282.60      0.0       0.0   95624.99   26656.63      0.00
# 2       0.00      0.0       0.0   12295.08       0.00  12293.11
# 3  656478.19      0.0     245.9   82696.72  574025.90      0.00
# 4      14.67      0.0       0.0      24.45       0.00      8.80
#
# [5 rows x 56 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14925 entries, 0 to 14924
# Data columns (total 56 columns):
# folioviv      14925 non-null int64
# foliohog      14925 non-null int64
# numren        14925 non-null int64
# id_trabajo    14925 non-null int64
# tipoact       14925 non-null int64
# cose_cria     14925 non-null int64
# prep_deriv    14925 non-null object
# otro_pago     14925 non-null int64
# fpago_1       14925 non-null object
# fpago_2       14925 non-null object
# fpago_3       14925 non-null object
# fpago_4       14925 non-null object
# fpago_5       14925 non-null object
# fpago_6       14925 non-null object
# fpago_7       14925 non-null object
# fpago_8       14925 non-null object
# nofpago       14925 non-null object
# t_emp         14925 non-null int64
# h_emp         14925 non-null object
# m_emp         14925 non-null object
# t_cpago       14925 non-null object
# h_cpago       14925 non-null object
# m_cpago       14925 non-null object
# t_ispago      14925 non-null object
# h_ispago      14925 non-null object
# m_ispago      14925 non-null object
# t_nispago     14925 non-null object
# h_nispago     14925 non-null object
# m_nispago     14925 non-null object
# valrema       14925 non-null object
# valproc       14925 non-null object
# apoyo         14925 non-null int64
# apoyo_1       14925 non-null object
# apoyo_2       14925 non-null object
# apoyo_3       14925 non-null object
# apoyo_4       14925 non-null object
# apoyo_5       14925 non-null object
# apoyo_6       14925 non-null object
# apoyo_7       14925 non-null object
# apoyo_8       14925 non-null object
# procampo      14925 non-null object
# mesproc       14925 non-null object
# progan        14925 non-null object
# mesprogan     14925 non-null object
# reg_not       14925 non-null int64
# reg_cont      14925 non-null int64
# ventas        14925 non-null int64
# autocons      14925 non-null int64
# otrosnom      14925 non-null int64
# gasneg        14925 non-null int64
# ventas_tri    14925 non-null float64
# auto_tri      14925 non-null float64
# otros_tri     14925 non-null float64
# gasto_tri     14925 non-null float64
# ing_tri       14925 non-null float64
# ero_tri       14925 non-null float64
# dtypes: float64(6), int64(15), object(35)
# memory usage: 6.4+ MB

# %%
df.shape#para ver las dimensiones del conjunto de datos
# Out:
# (14925, 56)

# %%
df.columns.values.tolist()
# Out:
# ['folioviv',
#  'foliohog',
#  'numren',
#  'id_trabajo',
#  'tipoact',
#  'cose_cria',
#  'prep_deriv',
#  'otro_pago',
#  'fpago_1',
#  'fpago_2',
#  'fpago_3',
#  'fpago_4',
#  'fpago_5',
#  'fpago_6',
#  'fpago_7',
#  'fpago_8',
#  'nofpago',
#  't_emp',
#  'h_emp',
#  'm_emp',
#  't_cpago',
#  'h_cpago',
#  'm_cpago',
#  't_ispago',
#  'h_ispago',
#  'm_ispago',
#  't_nispago',
#  'h_nispago',
#  'm_nispago',
#  'valrema',
#  'valproc',
#  'apoyo',
#  'apoyo_1',
#  'apoyo_2',
#  'apoyo_3',
#  'apoyo_4',
#  'apoyo_5',
#  'apoyo_6',
#  'apoyo_7',
#  'apoyo_8',
#  'procampo',
#  'mesproc',
#  'progan',
#  'mesprogan',
#  'reg_not',
#  'reg_cont',
#  'ventas',
#  'autocons',
#  'otrosnom',
#  'gasneg',
#  'ventas_tri',
#  'auto_tri',
#  'otros_tri',
#  'gasto_tri',
#  'ing_tri',
#  'ero_tri']

# %%
df.dtypes
# Out:
# folioviv        int64
# foliohog        int64
# numren          int64
# id_trabajo      int64
# tipoact         int64
# cose_cria       int64
# prep_deriv     object
# otro_pago       int64
# fpago_1        object
# fpago_2        object
# fpago_3        object
# fpago_4        object
# fpago_5        object
# fpago_6        object
# fpago_7        object
# fpago_8        object
# nofpago        object
# t_emp           int64
# h_emp          object
# m_emp          object
# t_cpago        object
# h_cpago        object
# m_cpago        object
# t_ispago       object
# h_ispago       object
# m_ispago       object
# t_nispago      object
# h_nispago      object
# m_nispago      object
# valrema        object
# valproc        object
# apoyo           int64
# apoyo_1        object
# apoyo_2        object
# apoyo_3        object
# apoyo_4        object
# apoyo_5        object
# apoyo_6        object
# apoyo_7        object
# apoyo_8        object
# procampo       object
# mesproc        object
# progan         object
# mesprogan      object
# reg_not         int64
# reg_cont        int64
# ventas          int64
# autocons        int64
# otrosnom        int64
# gasneg          int64
# ventas_tri    float64
# auto_tri      float64
# otros_tri     float64
# gasto_tri     float64
# ing_tri       float64
# ero_tri       float64
# dtype: object

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True) #espacios reemplazados con nan

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.bar(df) #todo lo que este debajo del 80

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['prep_deriv',
#  'fpago_1',
#  'fpago_2',
#  'fpago_3',
#  'fpago_4',
#  'fpago_5',
#  'fpago_6',
#  'fpago_7',
#  'fpago_8',
#  'nofpago',
#  'h_emp',
#  'm_emp',
#  't_cpago',
#  'h_cpago',
#  'm_cpago',
#  't_ispago',
#  'h_ispago',
#  'm_ispago',
#  't_nispago',
#  'h_nispago',
#  'm_nispago',
#  'valrema',
#  'valproc',
#  'apoyo_1',
#  'apoyo_2',
#  'apoyo_3',
#  'apoyo_4',
#  'apoyo_5',
#  'apoyo_6',
#  'apoyo_7',
#  'apoyo_8',
#  'procampo',
#  'mesproc',
#  'progan',
#  'mesprogan']

# %%
df.describe()
# Out:
#            folioviv      foliohog        numren    id_trabajo       tipoact  \
# count  1.492500e+04  14925.000000  14925.000000  14925.000000  14925.000000
# mean   1.841456e+09      1.004958      1.384925      1.239799      4.595980
# std    8.765220e+08      0.072124      0.758743      0.426975      0.795313
# min    1.003175e+08      1.000000      1.000000      1.000000      4.000000
# 25%    1.161174e+09      1.000000      1.000000      1.000000      4.000000
# 50%    1.860410e+09      1.000000      1.000000      1.000000      5.000000
# 75%    2.560551e+09      1.000000      2.000000      1.000000      5.000000
# max    3.260799e+09      3.000000     12.000000      2.000000      9.000000
#
#           cose_cria     otro_pago         t_emp         apoyo  reg_not  ...  \
# count  14925.000000  14925.000000  14925.000000  14925.000000  14925.0  ...
# mean       1.002747      1.970720      0.855075      1.923886      2.0  ...
# std        0.052342      0.168595      1.492758      0.265189      0.0  ...
# min        1.000000      1.000000      0.000000      1.000000      2.0  ...
# 25%        1.000000      2.000000      0.000000      2.000000      2.0  ...
# 50%        1.000000      2.000000      0.000000      2.000000      2.0  ...
# 75%        1.000000      2.000000      1.000000      2.000000      2.0  ...
# max        2.000000      2.000000     14.000000      2.000000      2.0  ...
#
#              ventas       autocons       otrosnom        gasneg    ventas_tri  \
# count  1.492500e+04   14925.000000   14925.000000  1.492500e+04  1.492500e+04
# mean   2.493059e+04    3058.463250      83.132127  1.546851e+04  6.121473e+03
# std    1.184336e+05    6774.615586    2174.137091  6.220150e+04  2.915321e+04
# min    0.000000e+00       0.000000       0.000000  0.000000e+00  0.000000e+00
# 25%    0.000000e+00       0.000000       0.000000  5.500000e+02  0.000000e+00
# 50%    1.300000e+03    1270.000000       0.000000  2.100000e+03  3.179300e+02
# 75%    1.205000e+04    3805.000000       0.000000  8.260000e+03  2.973910e+03
# max    6.750000e+06  402400.000000  220000.000000  1.828000e+06  1.678177e+06
#
#             auto_tri     otros_tri      gasto_tri       ing_tri        ero_tri
# count   14925.000000  14925.000000   14925.000000  1.492500e+04   14925.000000
# mean      751.052493     20.457512    3797.801142  3.813851e+03     719.248916
# std      1667.656881    538.547811   15278.586263  1.924913e+04    5893.089901
# min         0.000000      0.000000       0.000000  0.000000e+00       0.000000
# 25%         0.000000      0.000000     134.510000  0.000000e+00       0.000000
# 50%       312.790000      0.000000     513.580000  6.016300e+02       0.000000
# 75%       936.880000      0.000000    2029.890000  2.444670e+03       0.000000
# max    100044.190000  54696.130000  454475.130000  1.223700e+06  297132.060000
#
# [8 rows x 21 columns]

# %%
df.loc[[0]]
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria prep_deriv  \
# 0  100317506         1       1           1        4          1        NaN
#
#    otro_pago fpago_1 fpago_2  ... ventas autocons otrosnom gasneg ventas_tri  \
# 0          2     NaN     NaN  ...      0        0        0  80000        0.0
#
#   auto_tri otros_tri  gasto_tri ing_tri   ero_tri
# 0      0.0       0.0   19565.21     0.0  19563.26
#
# [1 rows x 56 columns]

# %%
df.loc[30:33]
# Out:
#      folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria prep_deriv  \
# 30  160006216         1       1           1        5          1          1
# 31  160006520         1       1           2        5          1          2
# 32  160006524         1       7           1        4          1        NaN
# 33  160006524         1       7           1        5          1          1
#
#     otro_pago fpago_1 fpago_2  ...  ventas autocons otrosnom  gasneg  \
# 30          2     NaN     NaN  ...  976220        0        0  432000
# 31          2     NaN     NaN  ...   76000        0        0   36000
# 32          2     NaN     NaN  ...       0        0        0    9000
# 33          2     NaN     NaN  ...   86124     3796        0   31200
#
#    ventas_tri auto_tri otros_tri  gasto_tri    ing_tri  ero_tri
# 30  242706.62     0.00       0.0  107403.31  135301.32     0.00
# 31   18586.95     0.00       0.0    8804.34    9781.63     0.00
# 32       0.00     0.00       0.0    2201.08       0.00  2201.08
# 33   21062.93   928.36       0.0    7630.43   14359.89     0.00
#
# [4 rows x 56 columns]

# %%
df.drop([0,24,51], axis=0).head()   #inplace: que si lo haga en el conjunto de datos
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria prep_deriv  \
# 1  100317506         1       1           1        5          1          2
# 2  100961704         1       1           2        4          1        NaN
# 3  100961704         1       1           2        5          1          1
# 4  101917906         1       1           2        7          1        NaN
# 5  101998619         1       1           1        4          1        NaN
#
#    otro_pago fpago_1 fpago_2  ...   ventas autocons otrosnom  gasneg  \
# 1          2     NaN     NaN  ...   500000        0        0  391000
# 2          1     NaN       2  ...        0        0        0   50000
# 3          1     NaN       2  ...  2669678        0     1000  336300
# 4          2     NaN     NaN  ...       60        0        0     100
# 5          2     NaN     NaN  ...        0        0        0    1000
#
#   ventas_tri auto_tri otros_tri  gasto_tri    ing_tri   ero_tri
# 1  122282.60      0.0       0.0   95624.99   26656.63      0.00
# 2       0.00      0.0       0.0   12295.08       0.00  12293.11
# 3  656478.19      0.0     245.9   82696.72  574025.90      0.00
# 4      14.67      0.0       0.0      24.45       0.00      8.80
# 5       0.00      0.0       0.0     245.90       0.00    244.91
#
# [5 rows x 56 columns]

# %%
df[100:].head() #df.tail(-100) )
# Out:
#       folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria prep_deriv  \
# 100  160215510         1       1           1        5          1          1
# 101  160229801         1       3           1        4          1        NaN
# 102  160229801         1       3           1        5          1          1
# 103  160229803         1       1           1        4          1        NaN
# 104  160229803         1       1           1        5          1          2
#
#      otro_pago fpago_1 fpago_2  ...  ventas autocons otrosnom gasneg  \
# 100          2     NaN     NaN  ...  141000     8700        0  58000
# 101          2     NaN     NaN  ...   44000        0        0  30000
# 102          2     NaN     NaN  ...   36480        0        0  29200
# 103          2     NaN     NaN  ...   39000      650        0  14600
# 104          2     NaN     NaN  ...  122500        0        0  36400
#
#     ventas_tri auto_tri otros_tri  gasto_tri   ing_tri ero_tri
# 100   34483.69  2127.71       0.0   14184.78  22424.67     0.0
# 101   10819.67     0.00       0.0    7377.04   3440.65     0.0
# 102    8970.49     0.00       0.0    7180.32   1788.19     0.0
# 103    9590.16   159.83       0.0    3590.16   6158.36     0.0
# 104   30122.95     0.00       0.0    8950.81  21172.13     0.0
#
# [5 rows x 56 columns]

# %%
df.apoyo.values
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int64)

# %%
df['apoyo'].values
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int64)

# %%
df.apoyo.unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df.apoyo.value_counts()
# Out:
# 2    13789
# 1     1136
# Name: apoyo, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria  \
# count       14925     14925   14925       14925    14925      14925
# size        14925     14925   14925       14925    14925      14925
# nunique     10159         3      11           2        6          2
#
#          prep_deriv  otro_pago  fpago_1  fpago_2  ...  ventas  autocons  \
# count          6996      14925        7      101  ...   14925     14925
# size          14925      14925    14925    14925  ...   14925     14925
# nunique           2          2        1        1  ...    3217      3606
#
#          otrosnom  gasneg  ventas_tri  auto_tri  otros_tri  gasto_tri  \
# count       14925   14925       14925     14925      14925      14925
# size        14925   14925       14925     14925      14925      14925
# nunique       171    3536        4182      5058        254       4941
#
#          ing_tri  ero_tri
# count      14925    14925
# size       14925    14925
# nunique     4781     1763
#
# [3 rows x 56 columns]

# %%
df.groupby('apoyo').agg(['count', 'size', 'nunique']).stack()
# Out:
#                folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria  \
# apoyo
# 1     count        1136      1136    1136        1136     1136       1136
#       size         1136      1136    1136        1136     1136       1136
#       nunique      1084         2       9           2        4          2
# 2     count       13789     13789   13789       13789    13789      13789
#       size        13789     13789   13789       13789    13789      13789
#       nunique      9642         3      11           2        6          2
#
#                prep_deriv  otro_pago  fpago_1  fpago_2  ...  ventas  autocons  \
# apoyo                                                   ...
# 1     count           237       1136        1       16  ...    1136      1136
#       size           1136       1136     1136     1136  ...    1136      1136
#       nunique           2          2        1        1  ...     564       645
# 2     count          6759      13789        6       85  ...   13789     13789
#       size          13789      13789    13789    13789  ...   13789     13789
#       nunique           2          2        1        1  ...    2966      3379
#
#                otrosnom  gasneg  ventas_tri  auto_tri  otros_tri  gasto_tri  \
# apoyo
# 1     count        1136    1136        1136      1136       1136       1136
#       size         1136    1136        1136      1136       1136       1136
#       nunique        43     742         644       751         48        855
# 2     count       13789   13789       13789     13789      13789      13789
#       size        13789   13789       13789     13789      13789      13789
#       nunique       158    3256        3851      4735        228       4564
#
#                ing_tri  ero_tri
# apoyo
# 1     count       1136     1136
#       size        1136     1136
#       nunique      766      270
# 2     count      13789    13789
#       size       13789    13789
#       nunique     4489     1623
#
# [6 rows x 55 columns]

# %%
df.groupby('apoyo').agg(['count', 'size', 'nunique'])
# Out:
#       folioviv                foliohog                numren                 \
#          count   size nunique    count   size nunique  count   size nunique
# apoyo
# 1         1136   1136    1084     1136   1136       2   1136   1136       9
# 2        13789  13789    9642    13789  13789       3  13789  13789      11
#
#       id_trabajo  ... otros_tri gasto_tri                ing_tri         \
#            count  ...   nunique     count   size nunique   count   size
# apoyo             ...
# 1           1136  ...        48      1136   1136     855    1136   1136
# 2          13789  ...       228     13789  13789    4564   13789  13789
#
#               ero_tri
#       nunique   count   size nunique
# apoyo
# 1         766    1136   1136     270
# 2        4489   13789  13789    1623
#
# [2 rows x 165 columns]

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria  \
# 5633   1361341224         1       1           2        5          1
# 3836   1161699824         1       1           1        4          1
# 13294  3063210319         1       1           1        4          1
# 8423   2060964308         1       1           2        5          1
# 9218   2062504406         1       3           2        5          1
#
#       prep_deriv  otro_pago fpago_1 fpago_2  ... ventas autocons otrosnom  \
# 5633           1          2     NaN     NaN  ...      0      800        0
# 3836         NaN          2     NaN     NaN  ...  33600    12680        0
# 13294        NaN          2     NaN     NaN  ...      0     2000        0
# 8423           1          2     NaN     NaN  ...    440     1305        0
# 9218           1          2     NaN     NaN  ...  22131     9060        0
#
#       gasneg ventas_tri auto_tri otros_tri  gasto_tri   ing_tri ero_tri
# 5633     300       0.00   198.89       0.0      74.58    122.32     0.0
# 3836    3300    8262.29  3118.03       0.0     811.47  10566.88     0.0
# 13294    780       0.00   489.13       0.0     190.76    296.41     0.0
# 8423     350     107.60   319.15       0.0      85.59    340.43     0.0
# 9218    8440    5412.47  2215.76       0.0    2064.13   5561.41     0.0
#
# [5 rows x 56 columns]

# %%
df.shape
# Out:
# (14925, 56)

# %%
df_sample.shape
# Out:
# (746, 56)

# %%
df_dropped = df.dropna(subset=['prep_deriv'])
df_dropped.head()
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria prep_deriv  \
# 1  100317506         1       1           1        5          1          2
# 3  100961704         1       1           2        5          1          1
# 6  101998619         1       1           1        5          1          2
# 7  101998802         1       1           2        5          1          2
# 9  102041503         1       1           2        5          1          2
#
#    otro_pago fpago_1 fpago_2  ...   ventas autocons otrosnom  gasneg  \
# 1          2     NaN     NaN  ...   500000        0        0  391000
# 3          1     NaN       2  ...  2669678        0     1000  336300
# 6          2     NaN     NaN  ...    18000        0        0     200
# 7          2     NaN     NaN  ...    30000        0        0   28250
# 9          2     NaN     NaN  ...        0        0        0     300
#
#   ventas_tri auto_tri otros_tri  gasto_tri    ing_tri ero_tri
# 1  122282.60      0.0       0.0   95624.99   26656.63    0.00
# 3  656478.19      0.0     245.9   82696.72  574025.90    0.00
# 6    4426.22      0.0       0.0      49.18    4376.06    0.00
# 7    7377.04      0.0       0.0    6946.72     427.86    0.00
# 9       0.00      0.0       0.0      73.36       0.00   73.36
#
# [5 rows x 56 columns]

# %%
df_dropped.shape
# Out:
# (6996, 56)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria prep_deriv  \
# 0  100317506         1       1           1        4          1        NaN
# 1  100317506         1       1           1        5          1          2
# 2  100961704         1       1           2        4          1        NaN
# 3  100961704         1       1           2        5          1          1
# 4  101917906         1       1           2        7          1        NaN
#
#    otro_pago fpago_1 fpago_2  ...   ventas autocons otrosnom  gasneg  \
# 0          2     NaN     NaN  ...        0        0        0   80000
# 1          2     NaN     NaN  ...   500000        0        0  391000
# 2          1     NaN       2  ...        0        0        0   50000
# 3          1     NaN       2  ...  2669678        0     1000  336300
# 4          2     NaN     NaN  ...       60        0        0     100
#
#   ventas_tri auto_tri otros_tri  gasto_tri    ing_tri   ero_tri
# 0       0.00      0.0       0.0   19565.21       0.00  19563.26
# 1  122282.60      0.0       0.0   95624.99   26656.63      0.00
# 2       0.00      0.0       0.0   12295.08       0.00  12293.11
# 3  656478.19      0.0     245.9   82696.72  574025.90      0.00
# 4      14.67      0.0       0.0      24.45       0.00      8.80
#
# [5 rows x 56 columns]

# %%
df_copy.shape
# Out:
# (14925, 56)

# %%
df_dropped['ventas'].dtype
# Out:
# dtype('int64')

# %%
df_dropped['ventas'].mean()
# Out:
# 20135.286878216124

# %%
df_copy['ventas'].fillna(value=np.round(df['ventas'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria  \
# count       14925     14925   14925       14925    14925      14925
# size        14925     14925   14925       14925    14925      14925
# nunique     10159         3      11           2        6          2
#
#          prep_deriv  otro_pago  fpago_1  fpago_2  ...  ventas  autocons  \
# count          6996      14925        7      101  ...   14925     14925
# size          14925      14925    14925    14925  ...   14925     14925
# nunique           2          2        1        1  ...    3217      3606
#
#          otrosnom  gasneg  ventas_tri  auto_tri  otros_tri  gasto_tri  \
# count       14925   14925       14925     14925      14925      14925
# size        14925   14925       14925     14925      14925      14925
# nunique       171    3536        4182      5058        254       4941
#
#          ing_tri  ero_tri
# count      14925    14925
# size       14925    14925
# nunique     4781     1763
#
# [3 rows x 56 columns]

# %% [markdown]
# # Handling Categorical Data

# %%
list(df['tipoact'].unique())
# Out:
# [4, 5, 7, 6, 9, 8]

# %%
df['tipoact'].replace({4:"agrícolas", 
                       5:"animales",
                       7:"recolección", 
                       6:"tala", 
                       9:"caza", 
                       8:"pesca"}, inplace=True)

# %%
list(df['tipoact'].unique())
# Out:
# ['agrícolas', 'animales', 'recolección', 'tala', 'caza', 'pesca']

# %%
keys = list(df['tipoact'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'agrícolas': 1,
#  'animales': 2,
#  'recolección': 3,
#  'tala': 4,
#  'caza': 5,
#  'pesca': 6}

# %%
df_copy['tipoact_cat'] = df['tipoact'].map(act)
df_copy.head()
# Out:
#     folioviv  foliohog  numren  id_trabajo  tipoact  cose_cria prep_deriv  \
# 0  100317506         1       1           1        4          1        NaN
# 1  100317506         1       1           1        5          1          2
# 2  100961704         1       1           2        4          1        NaN
# 3  100961704         1       1           2        5          1          1
# 4  101917906         1       1           2        7          1        NaN
#
#    otro_pago fpago_1 fpago_2  ... autocons otrosnom  gasneg ventas_tri  \
# 0          2     NaN     NaN  ...        0        0   80000       0.00
# 1          2     NaN     NaN  ...        0        0  391000  122282.60
# 2          1     NaN       2  ...        0        0   50000       0.00
# 3          1     NaN       2  ...        0     1000  336300  656478.19
# 4          2     NaN     NaN  ...        0        0     100      14.67
#
#   auto_tri otros_tri gasto_tri    ing_tri   ero_tri tipoact_cat
# 0      0.0       0.0  19565.21       0.00  19563.26           1
# 1      0.0       0.0  95624.99   26656.63      0.00           2
# 2      0.0       0.0  12295.08       0.00  12293.11           1
# 3      0.0     245.9  82696.72  574025.90      0.00           2
# 4      0.0       0.0     24.45       0.00      8.80           3
#
# [5 rows x 57 columns]

# %%
list(df_copy['tipoact_cat'].unique())
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# # Data Summarization

# %%
df_copy['ventas'].mean()
# Out:
# 24930.588408710217

# %%
df_copy['ventas'][df_copy['tipoact'] == 6]
# Out:
# 10       32970
# 38       25680
# 223      10750
# 243      85834
# 399       5520
#          ...
# 14373    12960
# 14379    42593
# 14451    44500
# 14486     2625
# 14492     3780
# Name: ventas, Length: 261, dtype: int64

# %%
df_copy['ventas'][df_copy['tipoact_cat'] == 6].mean()
# Out:
# 2914.6666666666665

# %%
df_copy.groupby(["tipoact_cat", "cose_cria", "prep_deriv", "otro_pago"]).count()
# Out:
#                                             folioviv  foliohog  numren  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                 1         1       1
#                                  2                29        29      29
#                       2          2                 9         9       9
# 2           1         1          1                71        71      71
#                                  2              4443      4443    4443
#                       2          1                86        86      86
#                                  2              2357      2357    2357
#
#                                             id_trabajo  tipoact  fpago_1  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                   1        1        0
#                                  2                  29       29        0
#                       2          2                   9        9        0
# 2           1         1          1                  71       71        3
#                                  2                4443     4443        0
#                       2          1                  86       86        1
#                                  2                2357     2357        0
#
#                                             fpago_2  fpago_3  fpago_4  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                0        0        0
#                                  2                0        0        0
#                       2          2                0        0        0
# 2           1         1          1                6        0        2
#                                  2                0        0        0
#                       2          1               16        0        1
#                                  2                0        0        0
#
#                                             fpago_5  ...  ventas  autocons  \
# tipoact_cat cose_cria prep_deriv otro_pago           ...
# 1           2         1          1                0  ...       1         1
#                                  2                0  ...      29        29
#                       2          2                0  ...       9         9
# 2           1         1          1               55  ...      71        71
#                                  2                0  ...    4443      4443
#                       2          1               68  ...      86        86
#                                  2                0  ...    2357      2357
#
#                                             otrosnom  gasneg  ventas_tri  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                 1       1           1
#                                  2                29      29          29
#                       2          2                 9       9           9
# 2           1         1          1                71      71          71
#                                  2              4443    4443        4443
#                       2          1                86      86          86
#                                  2              2357    2357        2357
#
#                                             auto_tri  otros_tri  gasto_tri  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                 1          1          1
#                                  2                29         29         29
#                       2          2                 9          9          9
# 2           1         1          1                71         71         71
#                                  2              4443       4443       4443
#                       2          1                86         86         86
#                                  2              2357       2357       2357
#
#                                             ing_tri  ero_tri
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                1        1
#                                  2               29       29
#                       2          2                9        9
# 2           1         1          1               71       71
#                                  2             4443     4443
#                       2          1               86       86
#                                  2             2357     2357
#
# [7 rows x 53 columns]

# %%
df_copy.groupby(["tipoact_cat", "cose_cria", "prep_deriv", "otro_pago"]).count()
# Out:
#                                             folioviv  foliohog  numren  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                 1         1       1
#                                  2                29        29      29
#                       2          2                 9         9       9
# 2           1         1          1                71        71      71
#                                  2              4443      4443    4443
#                       2          1                86        86      86
#                                  2              2357      2357    2357
#
#                                             id_trabajo  tipoact  fpago_1  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                   1        1        0
#                                  2                  29       29        0
#                       2          2                   9        9        0
# 2           1         1          1                  71       71        3
#                                  2                4443     4443        0
#                       2          1                  86       86        1
#                                  2                2357     2357        0
#
#                                             fpago_2  fpago_3  fpago_4  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                0        0        0
#                                  2                0        0        0
#                       2          2                0        0        0
# 2           1         1          1                6        0        2
#                                  2                0        0        0
#                       2          1               16        0        1
#                                  2                0        0        0
#
#                                             fpago_5  ...  ventas  autocons  \
# tipoact_cat cose_cria prep_deriv otro_pago           ...
# 1           2         1          1                0  ...       1         1
#                                  2                0  ...      29        29
#                       2          2                0  ...       9         9
# 2           1         1          1               55  ...      71        71
#                                  2                0  ...    4443      4443
#                       2          1               68  ...      86        86
#                                  2                0  ...    2357      2357
#
#                                             otrosnom  gasneg  ventas_tri  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                 1       1           1
#                                  2                29      29          29
#                       2          2                 9       9           9
# 2           1         1          1                71      71          71
#                                  2              4443    4443        4443
#                       2          1                86      86          86
#                                  2              2357    2357        2357
#
#                                             auto_tri  otros_tri  gasto_tri  \
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                 1          1          1
#                                  2                29         29         29
#                       2          2                 9          9          9
# 2           1         1          1                71         71         71
#                                  2              4443       4443       4443
#                       2          1                86         86         86
#                                  2              2357       2357       2357
#
#                                             ing_tri  ero_tri
# tipoact_cat cose_cria prep_deriv otro_pago
# 1           2         1          1                1        1
#                                  2               29       29
#                       2          2                9        9
# 2           1         1          1               71       71
#                                  2             4443     4443
#                       2          1               86       86
#                                  2             2357     2357
#
# [7 rows x 53 columns]

# %%
df_copy.tipoact
# Out:
# 0        4
# 1        5
# 2        4
# 3        5
# 4        7
#         ..
# 14920    5
# 14921    4
# 14922    5
# 14923    4
# 14924    5
# Name: tipoact, Length: 14925, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          folioviv  foliohog  numren  id_trabajo    tipoact  cose_cria  \
# 5633   1361341224         1       1           2   animales          1
# 3836   1161699824         1       1           1  agrícolas          1
# 13294  3063210319         1       1           1  agrícolas          1
# 8423   2060964308         1       1           2   animales          1
# 9218   2062504406         1       3           2   animales          1
#
#       prep_deriv  otro_pago fpago_1 fpago_2  ... ventas autocons otrosnom  \
# 5633           1          2     NaN     NaN  ...      0      800        0
# 3836         NaN          2     NaN     NaN  ...  33600    12680        0
# 13294        NaN          2     NaN     NaN  ...      0     2000        0
# 8423           1          2     NaN     NaN  ...    440     1305        0
# 9218           1          2     NaN     NaN  ...  22131     9060        0
#
#       gasneg ventas_tri auto_tri otros_tri  gasto_tri   ing_tri ero_tri
# 5633     300       0.00   198.89       0.0      74.58    122.32     0.0
# 3836    3300    8262.29  3118.03       0.0     811.47  10566.88     0.0
# 13294    780       0.00   489.13       0.0     190.76    296.41     0.0
# 8423     350     107.60   319.15       0.0      85.59    340.43     0.0
# 9218    8440    5412.47  2215.76       0.0    2064.13   5561.41     0.0
#
# [5 rows x 56 columns]

# %%
df_sample.groupby(["tipoact", "cose_cria"])[["prep_deriv", "otro_pago"]].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                       otro_pago
#                             sum      mean count_nonzero
# tipoact     cose_cria
# agrícolas   1               729  1.970270           370
#             2                 4  2.000000             2
# animales    1               686  1.971264           348
#             2                 2  2.000000             1
# caza        1                18  1.800000            10
# recolección 1                 2  2.000000             1
# tala        1                28  2.000000            14

# %%
df_sample.groupby(["tipoact", "cose_cria"]).agg({'ventas':np.mean,'otro_pago':np.max})
# Out:
#                               ventas  otro_pago
# tipoact     cose_cria
# agrícolas   1           23868.200000          2
#             2               0.000000          2
# animales    1           17341.959770          2
#             2               0.000000          2
# caza        1          108393.700000          2
# recolección 1            9000.000000          2
# tala        1           22991.285714          2
